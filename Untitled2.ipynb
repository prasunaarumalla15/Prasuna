# %%
import pandas as pd
dis=pd.read_csv('district.csv',parse_dates=['_CreatedDate'])
dis.head()
# Out:
#         StateName  state_id   DistrictName  DISTRICT_ID  TotalUAM  General  \
# 0  ANDHRA PRADESH        28     ANANTHAPUR          520      4666     1826
# 1  ANDHRA PRADESH        28        CHITOOR          511      9948     3457
# 2  ANDHRA PRADESH        28  EAST GODAVARI          512      7928     3463
# 3  ANDHRA PRADESH        28         GUNTUR          509      7900     4972
# 4  ANDHRA PRADESH        28        KRISHNA          517      7603     5110
#
#      SC   ST   OBC            _CreatedDate
# 0   786  273  1781 2019-08-06 08:25:25.900
# 1  2507  771  3213 2019-08-06 08:25:25.900
# 2  1641   96  2728 2019-08-06 08:25:25.900
# 3  1324  404  1200 2019-08-06 08:25:25.900
# 4   977  172  1344 2019-08-06 08:25:25.900

# %%
dis.columns
# Out:
# Index(['StateName', 'state_id', 'DistrictName', 'DISTRICT_ID', 'TotalUAM',
#        'General', 'SC', 'ST', 'OBC', '_CreatedDate'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
dis['StateName'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU AND KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TELANGANA', 'TRIPURA', 'UTTAR PRADESH',
#        'UTTARAKHAND', 'WEST BENGAL', 'ANDAMAN AND NICOBAR ISLANDS',
#        'CHANDIGARH', 'DADAR AND NAGAR HAVELI', 'DAMAN AND DIU', 'DELHI ',
#        'LAKSHADWEEP', 'PUDUCHERRY'], dtype=object)

# %%
disA=dis[dis.StateName=='ANDHRA PRADESH']

# %%
disA
# Out:
#          StateName  state_id   DistrictName  DISTRICT_ID  TotalUAM  General  \
# 0   ANDHRA PRADESH        28     ANANTHAPUR          520      4666     1826
# 1   ANDHRA PRADESH        28        CHITOOR          511      9948     3457
# 2   ANDHRA PRADESH        28  EAST GODAVARI          512      7928     3463
# 3   ANDHRA PRADESH        28         GUNTUR          509      7900     4972
# 4   ANDHRA PRADESH        28        KRISHNA          517      7603     5110
# 5   ANDHRA PRADESH        28        KURNOOL          506      6924     3294
# 6   ANDHRA PRADESH        28       PRAKASAM          510     24125     6095
# 7   ANDHRA PRADESH        28   SPSR NELLORE          518     45332     6400
# 8   ANDHRA PRADESH        28     SRIKAKULAM          522      2105      488
# 9   ANDHRA PRADESH        28  VISAKHAPATNAM          519      9246     4957
# 10  ANDHRA PRADESH        28   VIZIANAGARAM          513     11478     3029
# ...

# %%
DA=dis[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
DA.head()
# Out:
#    DISTRICT_ID  General    SC   ST   OBC
# 0          520     1826   786  273  1781
# 1          511     3457  2507  771  3213
# 2          512     3463  1641   96  2728
# 3          509     4972  1324  404  1200
# 4          517     5110   977  172  1344

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('AP')
# Out:
# Text(0.5, 1.0, 'AP')

# %%
disAr=dis[dis.StateName=='ARUNACHAL PRADESH']

# %%
disAr.head()
# Out:
#             StateName  state_id   DistrictName  DISTRICT_ID  TotalUAM  \
# 13  ARUNACHAL PRADESH        12          ANJAW          628         6
# 14  ARUNACHAL PRADESH        12      CHANGLANG          269        20
# 15  ARUNACHAL PRADESH        12  DIBANG VALLEY          267         8
# 16  ARUNACHAL PRADESH        12    EAST KAMENG          260         7
# 17  ARUNACHAL PRADESH        12     EAST SIANG          265        20
#
#     General  SC  ST  OBC            _CreatedDate
# 13        1   0   0    5 2019-08-06 08:25:38.517
# 14       12   0   5    3 2019-08-06 08:25:38.517
# 15        2   1   1    4 2019-08-06 08:25:38.517
# 16        0   2   4    1 2019-08-06 08:25:38.517
# 17        5   1  12    2 2019-08-06 08:25:38.517

# %%
DA=disAr[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('Arunachal Pradesh')
# Out:
# Text(0.5, 1.0, 'Arunachal Pradesh')

# %%
disA=dis[dis.StateName=='ASSAM']

# %%
disA.head()
# Out:
#    StateName  state_id DistrictName  DISTRICT_ID  TotalUAM  General  SC  ST  \
# 30     ASSAM        18        BAKSA          651        43        9   6  17
# 31     ASSAM        18      BARPETA          311        98       86   2   1
# 32     ASSAM        18   BONGAIGAON          310        87       56   7   3
# 33     ASSAM        18       CACHAR          327       175      130  16   4
# 34     ASSAM        18      CHIRANG          652        44       21   3  15
#
#     OBC            _CreatedDate
# 30   11 2019-08-06 08:25:44.150
# 31    9 2019-08-06 08:25:44.150
# 32   21 2019-08-06 08:25:44.150
# 33   25 2019-08-06 08:25:44.150
# 34    5 2019-08-06 08:25:44.150

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('Assam')
# Out:
# Text(0.5, 1.0, 'Assam')

# %%
disA=dis[dis.StateName=='BIHAR']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('bihar')
# Out:
# Text(0.5, 1.0, 'bihar')

# %%
disA=dis[dis.StateName=='CHHATTISGARH']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('chhattisgarh')
# Out:
# Text(0.5, 1.0, 'chhattisgarh')

# %%
disA=dis[dis.StateName=='GOA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('goa')
# Out:
# Text(0.5, 1.0, 'goa')

# %%
disA=dis[dis.StateName=='GUJARAT']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('gujarat')
# Out:
# Text(0.5, 1.0, 'gujarat')

# %%
disA=dis[dis.StateName=='HARYANA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('haryana')
# Out:
# Text(0.5, 1.0, 'haryana')

# %%
disA=dis[dis.StateName=='HIMACHAL PRADESH']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('HP')
# Out:
# Text(0.5, 1.0, 'HP')

# %%
disA=dis[dis.StateName=='JAMMU AND KASHMIR']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('jammu and kashmir')
# Out:
# Text(0.5, 1.0, 'jammu and kashmir')

# %%
disA=dis[dis.StateName=='JHARKHAND']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('jharkhand')
# Out:
# Text(0.5, 1.0, 'jharkhand')

# %%
disA=dis[dis.StateName=='KARNATAKA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('karnataka')
# Out:
# Text(0.5, 1.0, 'karnataka')

# %%
disA=dis[dis.StateName=='KERALA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('kerala')
# Out:
# Text(0.5, 1.0, 'kerala')

# %%
disA=dis[dis.StateName=='MADHYA PRADESH']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('MP')
# Out:
# Text(0.5, 1.0, 'MP')

# %%
disA=dis[dis.StateName=='MAHARASHTRA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('maharashtra')
# Out:
# Text(0.5, 1.0, 'maharashtra')

# %%
disA=dis[dis.StateName=='MANIPUR']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('manipur')
# Out:
# Text(0.5, 1.0, 'manipur')

# %%
disA=dis[dis.StateName=='MEGHALAYA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('meghalaya')
# Out:
# Text(0.5, 1.0, 'meghalaya')

# %%
disA=dis[dis.StateName=='MIZORAM']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('mizoram')
# Out:
# Text(0.5, 1.0, 'mizoram')

# %%
disA=dis[dis.StateName=='NAGALAND']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('nagaland')
# Out:
# Text(0.5, 1.0, 'nagaland')

# %%
disA=dis[dis.StateName=='ODISHA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('odisha')
# Out:
# Text(0.5, 1.0, 'odisha')

# %%
disA=dis[dis.StateName=='PUNJAB']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('punjab')
# Out:
# Text(0.5, 1.0, 'punjab')

# %%
disA=dis[dis.StateName=='RAJASTHAN']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('rajasthan')
# Out:
# Text(0.5, 1.0, 'rajasthan')

# %%
disA=dis[dis.StateName=='SIKKIM']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('sikkim')
# Out:
# Text(0.5, 1.0, 'sikkim')

# %%
disA=dis[dis.StateName=='TAMIL NADU']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('tamil nadu')
# Out:
# Text(0.5, 1.0, 'tamil nadu')

# %%
disA=dis[dis.StateName=='TELANGANA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('telangana')
# Out:
# Text(0.5, 1.0, 'telangana')

# %%
disA=dis[dis.StateName=='TRIPURA']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('tripura')
# Out:
# Text(0.5, 1.0, 'tripura')

# %%
disA=dis[dis.StateName=='UTTAR PRADESH']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('UP')
# Out:
# Text(0.5, 1.0, 'UP')

# %%
disA=dis[dis.StateName=='UTTARAKHAND']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('uttarakhand')
# Out:
# Text(0.5, 1.0, 'uttarakhand')

# %%
disA=dis[dis.StateName=='WEST BENGAL']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('west bengal')
# Out:
# Text(0.5, 1.0, 'west bengal')

# %%
disA=dis[dis.StateName=='ANDAMAN AND NICOBAR ISLANDS']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('andaman and nicobar')
# Out:
# Text(0.5, 1.0, 'andaman and nicobar')

# %%
disA=dis[dis.StateName=='CHANDIGARH']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('chandigarh')
# Out:
# Text(0.5, 1.0, 'chandigarh')

# %%
disA=dis[dis.StateName=='DADAR AND NAGAR HAVELI']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('dadar and nagar haveli')
# Out:
# Text(0.5, 1.0, 'dadar and nagar haveli')

# %%
disA=dis[dis.StateName=='DAMAN AND DIU']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('daman and diu')
# Out:
# Text(0.5, 1.0, 'daman and diu')

# %%
disA=dis[dis.StateName=='DELHI']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('delhi')
# Out:
# Text(0.5, 1.0, 'delhi')

# %%
disA=dis[dis.StateName=='LAKSHADWEEP']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('lakshadweep')
# Out:
# Text(0.5, 1.0, 'lakshadweep')

# %%
disA=dis[dis.StateName=='PUDUCHERRY']

# %%
DA=disA[['DISTRICT_ID','General','SC','ST','OBC']]

# %%
plt.figure(figsize=(10,6))
plt.plot(DA['DISTRICT_ID'],DA['General'],'bo',label='General')
plt.plot(DA['DISTRICT_ID'],DA['SC'],'go',label='SC')
plt.plot(DA['DISTRICT_ID'],DA['ST'],'s',label='ST')
plt.plot(DA['DISTRICT_ID'],DA['OBC'],'.',label='OBC')
plt.xlabel('district id')
plt.legend()
plt.title('puducherry')
# Out:
# Text(0.5, 1.0, 'puducherry')

# %%
dis_group=dis[['StateName','_CreatedDate']]

# %%
dis_group.plot()
# Out:
# C:\Users\Personal\Anaconda3\lib\site-packages\matplotlib\legend.py:449: UserWarning: The handle <matplotlib.lines.Line2D object at 0x00000154EEE27A58> has a label of '_CreatedDate' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
